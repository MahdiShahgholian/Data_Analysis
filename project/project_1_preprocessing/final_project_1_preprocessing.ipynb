# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc; align:center">
# <font face="vazir" color="#0099cc">
# Preprocessing
# </font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# </font>
# </p>

# %% [markdown]
#
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# library
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: right;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# </font>
# </p>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# data
# </font>
# </h2>
#
#
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>InvoiceNumber</code>|	یک شماره‌ی ۶ رقمی که به‌طور منحصر به فرد به هر فاکتور اختصاص یافته است. اگر ابتدای این شماره با حرف C شروع شود، به این معنی است که آن فاکتور لغو شده است.|
# |<code>ProductCode</code>|یک شماره‌ی ۵ رقمی که به‌طور منحصر به فرد به هر نوع محصول اختصاص یافته است.|
# |<code>ProductName</code>|نام محصول|
# |<code>Quantity</code>|تعداد سفارش از یک نوع محصول در فاکتور|
# |<code>InvoiceDate</code>|تاریخ ایجاد فاکتور|
# |<code>UnitPrice</code>|قیمت یک نوع محصول به ازای یک واحد از آن|
# |<code>CusotmerId</code>|یک شماره‌ی ۵ رقمی که به‌طور منحصر به فرد به هر مشتری اختصاص یافته‌ است.|
# |<code>Country</code>|نام کشور محل سکونت مشتری|
#
# </font>
# </div>
# </center>

# %%
df = pd.read_excel('sales.xlsx', engine='openpyxl')
df
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 525456         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 525457         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525458         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525459         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525460         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [525461 rows x 8 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت اول
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     ابتدا فاکتورهایی که شناسه مشتری (<code>CustomerId</code>) آن‌ها موجود نیست را حذف میکنیم.
#     این کار را بر روی یک کپی از دیتافریم به نام <code>df_no_missing_CustomerId</code> انجام میدهیم.
#
# </font>
# </p>

# %%
df_no_missing_CustomerId = df.copy()

df_no_missing_CustomerId = df_no_missing_CustomerId.dropna(subset=['CustomerId'])

df_no_missing_CustomerId
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 525456         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 525457         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525458         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525459         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525460         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [417534 rows x 8 columns]

# %% [markdown]
#
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت دوم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# سپس از بین سطر‌هایی که تمامی مقادیر آن‌ها تکراری هستند، فقط یک سطر را نگه میداریم.
# </font>
# </p>

# %%
df_no_duplicate = df_no_missing_CustomerId.copy()

df_no_duplicate = df_no_duplicate.drop_duplicates()

df_no_duplicate
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 525456         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 525457         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525458         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525459         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525460         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [410763 rows x 8 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت سوم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# همچنین سطرهایی که قیمت (<code>UnitPrice</code>) آن‌ها صفر
# </font>
# </p>

# %%
df_no_missing_price = df_no_duplicate.copy()

df_no_missing_price = df_no_missing_price[df_no_missing_price['UnitPrice'] > 0]

df_no_missing_price
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 525456        538171       22271                 FELTCRAFT DOLL ROSIE
# 525457        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 525458        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 525459        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 525456         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 525457         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525458         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525459         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 525460         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [410732 rows x 8 columns]

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت چهارم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#     اکنون طبق داده‌هایی که در مرحله‌ی قبل به دست آمدند (دیتافریم <code>df_no_missing_price</code>)، محاسبه کنید که چند درصد از کل سفارش‌ها لغو شده‌اند و عدد رُند شده‌ی آن را در متغیری به نام <code>percentage_cancelled_orders</code> ذخیره کنید. که چند درصد از کل سفارش‌ها، لغو شده‌اند.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <span style="color:green"><b>راهنمایی ۱:</b></span>
# چون ممکن است یک سفارش شامل بیش از یک محصول باشد، این احتمال وجود دارد که شناسه‌ی یک سفارش در چند ردیف تکرار شده باشد. برای محاسبه‌ی درصد سفارشات لغوشده، باید هر سفارش را تنها یک‌بار لحاظ کنید.
# <br>
# <span style="color:green"><b>راهنمایی ۲:</b></span>
# در صورتی‌که مقدار ستون <code>InvoiceNumber</code> با حرف <code>C</code> شروع شده باشد به این معنی‌ست که آن سفارش لغو شده است.
# <br>
# <span style="color:green"><b>راهنمایی ۳:</b></span>
# برای رُند کردن عدد از <code>round</code> استفاده کنید تا به‌عنوان مثال اگر عدد حاصل ۲۹/۸۷ درصد بود به عدد ۳۰ تبدیل شود.
# <br>
#
# </font>
# </p>

# %%
df.isna().sum()
# Out:
# InvoiceNumber         0
# ProductCode           0
# ProductName        2928
# Quantity              0
# InvoiceDate           0
# UnitPrice             0
# CustomerId       107927
# Country               0
# dtype: int64

# %%
df_no_missing_price.iloc[175]
# Out:
# InvoiceNumber                 489448
# ProductCode                    20825
# ProductName          GOLD WINE GLASS
# Quantity                          48
# InvoiceDate      2009-12-01 10:18:00
# UnitPrice                       3.39
# CustomerId                   15413.0
# Country               United Kingdom
# Name: 175, dtype: object

# %%
percentage_cancelled_orders = round(len(df_no_missing_price['InvoiceNumber'].str.startswith('c').dropna().index) / len(set(df_no_missing_price['InvoiceNumber'])) * 100)
percentage_cancelled_orders
# Out:
# 42

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت پنچم</font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این قسمت باید به کمک دیتافریم <code>df_no_missing_price</code> پنج مشتری با بیشترین تعداد دفعات لغو سفارش را پیدا کرده و شناسه‌های آن‌ها را در قالب یک لیست (به‌ترتیب نزولی) در متغیر <code>top_cancelling_customers</code> ذخیره کنید. توجه داشته باشید که مقادیر ستون <code>CustomerId</code> از جنس عدد <code>float</code> هستند اما مقادیر لیست خروجی شما باید از جنس رشته (<code>str</code>) باشند.
# </font>
# </p>
#
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# <span style="color:green"><b>راهنمایی:</b></span>
# در این قسمت هم به احتمال تکراری بودن شناسه‌ی سفارش‌ها دقت کنید. برای هر مشتری باید تعداد سفارش‌های یکتای لغوشده را محاسبه کنید.
# </font>
# </p>

# %%
index = list(df_no_missing_price['InvoiceNumber'].str.startswith('c').dropna().index)
index
# Out:
# [178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  207,
#  208,
#  285,
#  316,
#  317,
#  318,
#  399,
#  400,
#  401,
#  576,
#  589,
#  590,
#  591,
#  626,
#  677,
#  734,
#  735,
#  736,
#  926,
#  927,
#  933,
#  953,
#  1110,
#  1134,
#  1160,
#  1161,
#  1162,
#  1163,
#  1164,
#  1353,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1361,
#  1376,
#  1423,
#  1424,
#  1425,
#  1426,
#  1427,
#  1428,
#  1429,
#  1430,
#  1663,
#  1664,
#  1665,
#  1683,
#  1726,
#  1727,
#  1728,
#  1729,
#  1760,
#  1761,
#  1762,
#  1763,
#  1764,
#  1765,
#  1793,
#  1824,
#  1876,
#  2645,
#  2724,
#  2725,
#  2726,
#  2727,
#  2728,
#  2729,
#  2866,
#  2867,
#  2890,
#  2891,
#  2892,
#  2893,
#  2894,
#  2895,
#  24422,
#  24423,
#  24424,
#  24425,
#  24426,
#  24427,
#  24428,
#  24429,
#  24430,
#  24431,
#  24432,
#  24433,
#  24434,
#  24435,
#  24436,
#  24437,
#  24438,
#  24439,
#  24440,
#  24441,
#  24514,
#  24515,
#  24675,
#  24694,
#  24695,
#  24696,
#  24817,
#  24818,
#  24819,
#  24820,
#  24821,
#  24822,
#  24866,
#  24867,
#  25001,
#  25066,
#  25067,
#  25068,
#  25069,
#  25070,
#  25071,
#  25072,
#  25073,
#  25074,
#  25075,
#  25105,
#  25106,
#  25107,
#  25108,
#  25109,
#  25110,
#  25111,
#  25113,
#  25164,
#  25165,
#  25229,
#  25303,
#  25304,
#  25305,
#  25306,
#  25344,
#  25345,
#  25346,
#  25347,
#  25348,
#  25349,
#  25350,
#  25351,
#  25453,
#  25454,
#  25455,
#  25456,
#  25457,
#  25458,
#  25459,
#  25460,
#  25461,
#  25462,
#  25463,
#  25464,
#  25465,
#  25466,
#  25467,
#  25468,
#  25470,
#  25471,
#  25472,
#  25473,
#  25500,
#  25501,
#  25502,
#  25503,
#  25504,
#  25505,
#  25506,
#  25516,
#  25520,
#  25521,
#  25522,
#  25523,
#  25575,
#  25576,
#  25577,
#  25578,
#  25579,
#  25580,
#  25581,
#  25582,
#  25588,
#  25589,
#  25590,
#  25591,
#  25592,
#  25593,
#  25594,
#  25595,
#  25596,
#  25597,
#  25598,
#  25641,
#  25680,
#  25782,
#  25783,
#  26232,
#  26926,
#  26927,
#  26928,
#  26929,
#  27172,
#  27260,
#  27569,
#  27974,
#  28063,
#  28064,
#  28065,
#  28066,
#  28067,
#  28068,
#  28069,
#  28070,
#  28071,
#  28072,
#  28240,
#  28241,
#  28252,
#  28253,
#  28495,
#  28823,
#  29110,
#  29111,
#  29112,
#  29113,
#  29114,
#  29115,
#  29116,
#  29117,
#  29118,
#  29119,
#  29120,
#  29121,
#  29154,
#  29155,
#  29156,
#  29157,
#  29158,
#  29164,
#  29346,
#  29348,
#  29349,
#  29412,
#  29413,
#  29958,
#  32193,
#  32206,
#  32405,
#  32463,
#  32464,
#  32465,
#  33376,
#  33377,
#  33392,
#  33393,
#  33395,
#  33503,
#  33509,
#  33510,
#  34470,
#  35169,
#  35898,
#  35907,
#  35908,
#  36850,
#  37635,
#  37801,
#  38016,
#  38017,
#  38018,
#  38019,
#  38164,
#  38343,
#  38344,
#  38553,
#  38747,
#  38783,
#  38784,
#  38785,
#  38940,
#  38941,
#  38942,
#  38944,
#  38956,
#  38957,
#  38958,
#  38959,
#  38960,
#  38961,
#  38962,
#  38963,
#  38964,
#  38965,
#  38966,
#  38967,
#  38968,
#  38969,
#  38970,
#  39022,
#  39023,
#  39024,
#  39025,
#  39026,
#  39027,
#  39028,
#  39029,
#  39030,
#  39031,
#  39032,
#  39033,
#  39034,
#  39035,
#  39036,
#  39037,
#  39038,
#  39039,
#  39040,
#  39041,
#  39042,
#  39043,
#  39044,
#  39045,
#  39046,
#  39047,
#  39048,
#  39049,
#  39050,
#  39051,
#  39052,
#  39053,
#  39054,
#  39055,
#  39056,
#  39057,
#  39058,
#  39059,
#  39060,
#  39061,
#  39072,
#  39095,
#  39096,
#  39097,
#  39098,
#  39099,
#  39100,
#  39110,
#  39123,
#  39124,
#  39125,
#  39126,
#  39127,
#  39162,
#  39163,
#  39164,
#  39165,
#  39166,
#  39167,
#  39208,
#  39209,
#  39319,
#  39320,
#  39321,
#  39322,
#  39323,
#  39324,
#  39328,
#  39389,
#  39410,
#  39729,
#  40027,
#  40028,
#  40079,
#  40080,
#  41542,
#  41899,
#  41932,
#  41934,
#  41935,
#  41936,
#  41937,
#  41938,
#  41939,
#  42002,
#  42136,
#  42137,
#  42143,
#  42144,
#  42145,
#  42146,
#  42147,
#  42188,
#  42189,
#  42190,
#  42191,
#  42192,
#  42193,
#  42194,
#  42195,
#  42196,
#  42197,
#  42209,
#  42210,
#  42211,
#  42295,
#  42296,
#  42491,
#  42644,
#  43175,
#  43176,
#  43276,
#  43494,
#  43495,
#  43496,
#  43500,
#  43501,
#  43502,
#  43503,
#  43504,
#  43505,
#  43506,
#  43507,
#  43508,
#  43509,
#  43510,
#  43511,
#  43512,
#  43513,
#  43515,
#  43516,
#  43517,
#  43630,
#  43665,
#  43743,
#  43744,
#  43745,
#  43746,
#  43747,
#  43748,
#  43749,
#  43750,
#  43751,
#  43752,
#  43754,
#  43755,
#  43756,
#  43757,
#  43758,
#  43759,
#  43760,
#  43761,
#  43762,
#  43763,
#  43764,
#  43765,
#  43766,
#  43767,
#  43768,
#  43769,
#  43770,
#  43771,
#  43772,
#  43773,
#  43774,
#  43775,
#  43776,
#  43778,
#  43779,
#  43872,
#  44187,
#  44188,
#  44189,
#  44703,
#  44704,
#  44705,
#  44706,
#  44707,
#  44708,
#  44717,
#  44782,
#  45229,
#  45240,
#  45241,
#  ...]

# %%
df_no_missing_price = df_no_missing_price.reset_index()
df_no_missing_price.drop(columns=['index'], inplace=True)

# %%
df_no_missing_price
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 410727        538171       22271                 FELTCRAFT DOLL ROSIE
# 410728        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 410729        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 410730        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 410731        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 410727         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 410728         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410729         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410730         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410731         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [410732 rows x 8 columns]

# %%
index = df_no_missing_price['InvoiceNumber'].str.startswith('c').dropna().index.tolist()
df_cancel = df_no_missing_price.iloc[index]

# %%
df_cancel_uniq = df_cancel.drop_duplicates(subset=['InvoiceNumber'])

# %%
df_cancel_uniq['CustomerId'] = df_cancel_uniq['CustomerId'].astype(int)
# Out:
# <ipython-input-140-d5bfe4e2f6f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cancel_uniq['CustomerId'] = df_cancel_uniq['CustomerId'].astype(int)

# %%
top_cancelling_customers = df_cancel_uniq.groupby(['CustomerId'])['Quantity'].count().sort_values(ascending=False).iloc[0:5].index.tolist()

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قسمت ششم
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اکنون به‌عنوان آخرین مرحله‌ی پیش‌پردازش، ردیف‌های مربوط به سفارش‌های لغو شده را از دیتافریم حذف کنید. برای این کار از یک کپی از دیتافریم <code>df_no_missing_price</code> به نام <code>df_no_canceled_invoice</code> استفاده کنید و تغییرات خود را روی این دیتافریم اعمال کنید.
# </font>
# </p>

# %%
df_cancel
# Out:
#        InvoiceNumber ProductCode                       ProductName  Quantity  \
# 178          C489449       22087          PAPER BUNTING WHITE LACE       -12
# 179          C489449      85206A      CREAM FELT EASTER EGG BASKET        -6
# 180          C489449       21895     POTTING SHED SOW 'N' GROW SET        -4
# 181          C489449       21896                POTTING SHED TWINE        -6
# 182          C489449       22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...              ...         ...                               ...       ...
# 410359       C538123       22956          36 FOIL HEART CAKE CASES        -2
# 410360       C538124           M                            Manual        -4
# 410361       C538124       22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 410362       C538124       22423          REGENCY CAKESTAND 3 TIER        -1
# 410555       C538164      35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  UnitPrice  CustomerId         Country
# 178    2009-12-01 10:33:00       2.95     16321.0       Australia
# 179    2009-12-01 10:33:00       1.65     16321.0       Australia
# 180    2009-12-01 10:33:00       4.25     16321.0       Australia
# 181    2009-12-01 10:33:00       2.10     16321.0       Australia
# 182    2009-12-01 10:33:00       2.95     16321.0       Australia
# ...                    ...        ...         ...             ...
# 410359 2010-12-09 15:41:00       2.10     12605.0         Germany
# 410360 2010-12-09 15:43:00       0.50     15329.0  United Kingdom
# 410361 2010-12-09 15:43:00       2.95     15329.0  United Kingdom
# 410362 2010-12-09 15:43:00      12.75     15329.0  United Kingdom
# 410555 2010-12-09 17:32:00       1.95     14031.0  United Kingdom
#
# [9816 rows x 8 columns]

# %%
df_no_canceled_invoice = df_no_missing_price.copy()

df_no_canceled_invoice = df_no_canceled_invoice.drop(index = index)

df_no_canceled_invoice
# Out:
#        InvoiceNumber ProductCode                          ProductName  \
# 0             489434       85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1             489434      79323P                   PINK CHERRY LIGHTS
# 2             489434      79323W                  WHITE CHERRY LIGHTS
# 3             489434       22041         RECORD FRAME 7" SINGLE SIZE
# 4             489434       21232       STRAWBERRY CERAMIC TRINKET BOX
# ...              ...         ...                                  ...
# 410727        538171       22271                 FELTCRAFT DOLL ROSIE
# 410728        538171       22750         FELTCRAFT PRINCESS LOLA DOLL
# 410729        538171       22751       FELTCRAFT PRINCESS OLIVIA DOLL
# 410730        538171       20970   PINK FLORAL FELTCRAFT SHOULDER BAG
# 410731        538171       21931               JUMBO STORAGE BAG SUKI
#
#         Quantity         InvoiceDate  UnitPrice  CustomerId         Country
# 0             12 2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2             12 2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3             48 2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4             24 2009-12-01 07:45:00       1.25     13085.0  United Kingdom
# ...          ...                 ...        ...         ...             ...
# 410727         2 2010-12-09 20:01:00       2.95     17530.0  United Kingdom
# 410728         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410729         1 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410730         2 2010-12-09 20:01:00       3.75     17530.0  United Kingdom
# 410731         2 2010-12-09 20:01:00       1.95     17530.0  United Kingdom
#
# [400916 rows x 8 columns]

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# اکنون
# دیتافریم پیش‌پردازش‌شده را در فایلی به نام <code>preprocessed_sales.csv</code> ذخیره خواهیم کرد تا در گام‌های بعدی پروژه از این مجموعه‌داده استفاده کنید.
# </font>
# </p>

# %%
df_no_canceled_invoice.to_csv("preprocessed_sales.csv", index=False)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

joblib.dump(percentage_cancelled_orders, "percentage_cancelled_orders")
joblib.dump(top_cancelling_customers, "top_cancelling_customers")

df_no_missing_CustomerId.head(1000).to_csv("df_no_missing_CustomerId.csv", index=False)
df_no_duplicate.head(1000).to_csv("df_no_duplicate.csv", index=False)
df_no_missing_price.head(1000).to_csv("df_no_missing_price.csv", index=False)
df_no_canceled_invoice.head(1000).to_csv("df_no_canceled_invoice.csv", index=False)
remaining_invoices.to_csv("remaining_invoices.csv", index=False)

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ["df_no_canceled_invoice.csv", "df_no_missing_CustomerId.csv",
              "df_no_duplicate.csv", "df_no_missing_price.csv",
              "percentage_cancelled_orders", "top_cancelling_customers",
              "remaining_invoices.csv", "final_project_1_preprocessing.ipynb"]
compress(file_names)
